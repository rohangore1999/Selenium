# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\Rohan Gore\Documents\Selenium\chromedriver.exe")
#for j in range(1,2)

driver.get("https://guidestarindia.org/Organisation.aspx?CCReg=8361")

#for i in range(1,4):
link_path='//*[@id="search_form_container"]/div[1]/div/span/span[1]/span/span[2]'
driver.find_element_by_xpath(link_path).click()
#elem[0].send_keys(Keys.RETURN)
#driver.find_element_by_css_selector('#ngo_info_modal > div.modal-dialog.modal-lg > div > div.modal-header > button > span').click()
#elem = driver.find_elements_by_xpath('//*[@id="SectionPlaceHolder1_ctl01_ctpTxtCharityName"]/div/span[1]')
    #lst1.append(elem2.text)
#print(elem)
#print(elem[0].text)
#print(elem[0].get_attribute("Text"))
#elem.send_keys(Keys.RETURN)
#time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-45cce832c83b> in <module>()
#       6 #for i in range(1,4):
#       7 link_path='//*[@id="search_form_container"]/div[1]/div/span/span[1]/span/span[2]'
# ----> 8 driver.find_element_by_xpath(link_path).click()
#       9 #elem[0].send_keys(Keys.RETURN)
#      10 #driver.find_element_by_css_selector('#ngo_info_modal > div.modal-dialog.modal-lg > div > div.modal-header > button > span').click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     626             params = {}
# ...

# %%
elem=driver.find_elements_by_xpath('//*[@id="SectionPlaceHolder1"]/table[1]/tbody/tr[4]/td[2]/table/tbody/tr[1]/td[2]')
print(elem[0].text)
# Out:
# Address
# Lakshmikantapur, P.O. -Bijoygange Bazar,
# Mandir Bazar,
# Lakshmikantapur
# South 24 Parganas
# West Bengal
# 743343
# Telephone
# 91
# - -
# 9932934327
# Registered Address same as above

# %%
elem=driver.find_elements_by_xpath('//*[@id="SectionPlaceHolder1"]/table[1]/tbody/tr[4]/td[2]/table/tbody/tr[1]/td[1]/table/tbody/tr[2]/td[2]/span[2]/a')
print(elem[0].text)
# Out:
# aasharaalo1@gmail.com

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\Rohan Gore\Documents\Selenium\chromedriver.exe")
driver.get("https://ngodarpan.gov.in/index.php/home/statewise_ngo/49/35/1")
elem=driver.find_elements_by_xpath('/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr[1]/td[2]/a')
print(elem[0].text)
# Out:
# AdityaNatyaAcademy

# %%
link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr[1]/td[2]/a'
driver.find_element_by_xpath(link_path).click()

# %%
link_path1='//*[@id="UniqueID"]'
ele=driver.find_element_by_xpath(link_path1)
print(ele.text)
# Out:
# AN/2017/0161456

# %%
link_path2='//*[@id="ngo_city_p"]'
ele=driver.find_element_by_xpath(link_path2)
print(ele.text)
# Out:
# Port Blair

# %%
link_path3='//*[@id="printThis"]/div/div/table[2]/tbody'
ele=driver.find_element_by_xpath(link_path3)
print(ele.text)
# Out:
# Registered With Registrar of Companies
# Type of NGO Registered Societies (Non-Government)
# Registration No 888
# Copy of Registration Certificate Available
# Copy of Pan Card Available
# Act name Society Registration Act 1860
# City of Registration Port Blair
# State of Registration ANDAMAN & NICOBAR ISLANDS
# Date of Registration 05-12-1995

# %%
link_path4='//*[@id="member_table"]/tbody'
ele=driver.find_element_by_xpath(link_path4)
print(ele.text)
# Out:
# Name Designation Pan Aadhaar
# ASHUTOSH KARMAKAR President Available Available
# KAVERI DEBSHARMA Member Available Available
# SATYAJIT BAIN Asisstant Secretary Available Available

# %%
link_path5='//*[@id="printThis"]/div/div/table[4]/tbody'
ele=driver.find_element_by_xpath(link_path5)
print(ele.text)
# Out:
# Key Issues Not Available
# Operational Area-States ANDAMAN & NICOBAR ISLANDS
# Operational Area-District ANDAMAN & NICOBAR ISLANDS->South Andaman

# %%
link_path6='//*[@id="printThis"]/div/div/table[5]/tbody'
ele=driver.find_element_by_xpath(link_path6)
print(ele.text)
# Out:
# FCRA Available FCRA Registration no.
# Not Available Not Available

# %%
link_path7='//*[@id="printThis"]/div/div/table[6]/tbody'
ele=driver.find_element_by_xpath(link_path7)
print(ele.text)
# Out:
# .Drama Jatrapala Streetplays Awareness Programe

# %%
link_path8='//*[@id="source_table"]/tbody'
ele=driver.find_element_by_xpath(link_path8)
print(ele.text)
# Out:
# Department Name Source Finacial Year Amount Sanctioned Purpose
# Directorate of Art and Culture State 2013-2014 25000 To Promote Art and Culture in Andaman and Nicobar Islands.
# Directorate of Art and Culture State 2014-2015 25000 To promote Art and Culture
# Directorate of Art and Culture State 2015-2016 35000 To promote Art and Culture
# Directorate of Art and Culture State 2016-2017 25000 To promote Art and Culture

# %%
link_path9='//*[@id="printThis"]/div/div/table[8]/tbody'
ele=driver.find_element_by_xpath(link_path9)
print(ele.text)
# Out:
# Address 31 M.G. Road, Opp. Sun Sea Resort, Middle Point.
# City Port Blair
# State ANDAMAN & NICOBAR ISLANDS
# Telephone Not Available
# Mobile No 9476076176
# Website Url http://www.adityanatyaacademy.com
# E-mail anaportblair(at)gmail[dot]com

# %%
/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr[2]/td[2]/a

# %%
link_pathC='//*[@id="printThis"]/div/div'
ele1=driver.find_element_by_xpath(link_pathC)
print(ele1.text)
# Out:
# AdityaNatyaAcademy
# Unique Id of VO/NGO AN/2017/0161456
# Registration Details
# Registered With Registrar of Companies
# Type of NGO Registered Societies (Non-Government)
# Registration No 888
# Copy of Registration Certificate Available
# Copy of Pan Card Available
# Act name Society Registration Act 1860
# City of Registration Port Blair
# State of Registration ANDAMAN & NICOBAR ISLANDS
# Date of Registration 05-12-1995
# Members
# Name Designation Pan Aadhaar
# ASHUTOSH KARMAKAR President Available Available
# KAVERI DEBSHARMA Member Available Available
# SATYAJIT BAIN Asisstant Secretary Available Available
# Sector/ Key Issues
# Key Issues Not Available
# Operational Area-States ANDAMAN & NICOBAR ISLANDS
# Operational Area-District ANDAMAN & NICOBAR ISLANDS->South Andaman
# FCRA details
# FCRA Available FCRA Registration no.
# Not Available Not Available
# Details of Achievements
# .Drama Jatrapala Streetplays Awareness Programe
# Source of Funds
# ...

# %%
unique_id=[]
Registration_No_City_State=[]
Sectors_working=[]
Registered_with=[] 
Types_of_NGO=[]
Registration_No=[]
Copy_of_Registration_Certificate=[]
Copy_of_Pan_Card=[]
Act_name=[]
City_of_Registration=[]
State_of_Registration=[]
Date_of_Registration=[]
Key_Issues=[]
Operational_Area_States=[]
Operational_Area_District=[]
FCRA_Registration_no=[]
Address=[]
City=[]
State=[]
Telephone=[]
Mobile_No=[]
Website_Url=[]
E_mail=[]
Name=[]

# %%
for p in range(1,3):
    for i in range(1,101):

        link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[2]/a'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Name.append(ele.text)
        
        
        link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[3]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Registration_No_City_State.append(ele.text)
        

        link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[5]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Sectors_working.append(ele.text)
        
        

        #open
        link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[2]/a'
        driver.find_element_by_xpath(link_path).click()

        sleep(5)

        link_path1='//*[@id="UniqueID"]' 
        ele=driver.find_element_by_xpath(link_path1)
        print(ele.text)
        unique_id.append(ele.text)
        

        link_path='//*[@id="reg_with"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Registered_with.append(ele.text)
        

        link_path='//*[@id="ngo_type"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Types_of_NGO.append(ele.text)
        

        link_path='//*[@id="ngo_regno"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Registration_No.append(ele.text)
        

        link_path='//*[@id="rc_upload"]' 
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Copy_of_Registration_Certificate.append(ele.text)

        link_path='//*[@id="pc_upload"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Copy_of_Pan_Card.append(ele.text)

        link_path='//*[@id="ngo_act_name"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Act_name.append(ele.text)

        link_path='//*[@id="ngo_city_p"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        City_of_Registration.append(ele.text)

        link_path='//*[@id="ngo_state_p"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        State_of_Registration.append(ele.text)

        link_path='//*[@id="ngo_reg_date"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Date_of_Registration.append(ele.text)

        link_path='//*[@id="key_issues"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Key_Issues.append(ele.text)

        link_path='//*[@id="operational_states"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Operational_Area_States.append(ele.text)

        link_path='//*[@id="operational_district"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Operational_Area_District.append(ele.text)

        link_path='//*[@id="FCRA_reg_no"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        FCRA_Registration_no.append(ele.text)
        
        link_path='//*[@id="activities_achieve"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        FCRA_Registration_no.append(ele.text)

        link_path='//*[@id="address"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Address.append(ele.text)

        link_path='//*[@id="city"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        City.append(ele.text)

        link_path='//*[@id="state_p_ngo"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        State.append(ele.text)

        link_path='//*[@id="phone_n"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Telephone.append(ele.text)

        link_path='//*[@id="mobile_n"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Mobile_No.append(ele.text)

        link_path='//*[@id="ngo_web_url"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Website_Url.append(ele.text)

        link_path='//*[@id="email_n"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        E_mail.append(ele.text)







        #close
        link_path='//*[@id="ngo_info_modal"]/div[2]/div/div[1]/button/span'
        driver.find_element_by_xpath(link_path).click()
        sleep(5)
    
    sleep(5)
    #next page
    link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/ul/li[4]/a'
    driver.find_element_by_xpath(link_path).click()
    sleep(5)
    print("")
# Out:
# AASTHA
# 1030/Goa/2010, Mapusa (GOA)
# Differently Abled
# GA/2018/0191520
# Registrar of Societies
# Registered Societies (Non-Government)
# 1030/Goa/2010
# Available
# Available
# Societies Registration act 1860
# Mapusa
# GOA
# 15-12-2010
# Differently Abled
# GOA
# GOA->North Goa
# Not Available
# Started Anand Niketan special school for differently abled at Khorlim, Mapusa-Goa from April 2011. Started day care centre for special children. Started vocational centre for mentally challenged children. Started physiotherapy centre and speech therapy centre for special children. Organized All Goa Patriotic song competition for differently abled children of various special schools in Goa. Our students participated in various state and national level sports competition.
# Nr. Urban Health Centre, Ghateshwarnagar, Khorlim, Mapusa.
# Mapusa
# GOA
# Not Available
# 7744059796
# Not Available
# anandniketangoa(at)gmail[dot]com
# ABHIVYAKTEE
# 172/Goa/2001, Panaji (GOA)
# Art & Culture
# ...

# %%
list_ngo=pd.DataFrame(columns=['Name','Registration_No_City_State','Sectors_working','unique_id','Registered_with','Types_of_NGO','Registration_No','Copy_of_Registration_Certificate','Copy_of_Pan_Card','Act_name','City_of_Registration','State_of_Registration','Date_of_Registration','Operational_Area_States','Operational_Area_District','FCRA_Registration_no','activities_achieve','Address','City','State','Telephone','Mobile_No','Website_Url','E_mail'])

# %%
for j in range(2,10):
    for z in range(1,5):
        link_path = '//*[@id="member_table"]/tbody/tr['+str(j)+']/td['+str(z)+']'
        #link_path = '//*[@id="member_table"]/tbody/tr[2]/td[1]'
        elem=driver.find_elements_by_xpath(link_path)
        print(len(elem))
        if len(elem)>0:
            print(elem[0].text)
        else:
            break
# Out:
# 1
# NISHA MANGESH NAIK
# 1
# Secretary
# 1
# Available
# 1
# Available
# 1
# DILESHWAR MAHESHWAR NAIK
# 1
# Director
# 1
# Available
# 1
# Available
# 1
# UTTAM MURARI GOVEKAR
# 1
# Vice Chairman
# 1
# Available
# 1
# Available
# 1
# SHAMBA SHIVRAM DESAI
# 1
# Chairman
# 1
# Available
# 1
# Available
# 0
# 0
# 0
# 0

# %%
Name
# Out:
# ['AASTHA',
#  'ABHIVYAKTEE',
#  'ADARSH KRISHI KHAREDI VIKRI PRAKRIYA SAHAKARI SAUNSTHA MARYADIT',
#  'Adarsh Vidya prasarak mandal',
#  'AGNEL CHARITIES (AGNEL SEVA SANGH)',
#  'Al-Falah Educational Society',
#  'All India Womens Conference',
#  '']

# %%
Registration_No_City_State
len(Sectors_working)
#len(Registered_with)
#len(Types_of_NGO)
#len(Registration_No)
#len(Copy_of_Registration_Certificate)
#len(Copy_of_Pan_Card)
# Out:
# 8

# %%
Sectors_working
# Out:
# ['Differently Abled', '', '', '', '', '', '', '']

# %%
Registration_No_City_State
# Out:
# ['1030/Goa/2010, Mapusa (GOA)',
#  '172/Goa/2001, Panaji (GOA)',
#  '5/486/1993/ARS2/MKT, CANCOLIM BALI (GOA)',
#  '12/1964, SHIRODA (GOA)',
#  'Bom.301/1978, Margao (GOA)',
#  '24/Goa/94, FATORDA (GOA)',
#  '19/78, Panaji (GOA)',
#  '']

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\Rohan Gore\Documents\Selenium\chromedriver.exe")
driver.get("https://guidestarindia.org/Summary.aspx?CCReg=9089")

# %%
Head_Name_Designation_Email=[]
Organisation_Name_Designation_Email=[]
Beneficiary_Groups=[]
PAN_NO=[]

# %%
l
# Out:
# ['Shama',
#  'dd_natinal',
#  'ISLES Scientific Learning and Educational Society',
#  'Rural Care Ministries',
#  'RRHEDS ( Redemption Research for Health and Educational Development Society)',
#  "Serve Train Educate People's Society-STEPS",
#  'Sanga Mithra Development Association',
#  'Association for Social & Humanize Action',
#  'Technology & Innovation for Social Change',
#  'Welfare Organiosation for Rural League Development (WORLD)',
#  'sunlight educational society',
#  'MAHILA MARGADARSHI',
#  'Rural Development Trust',
#  'SRISAI RURAL DEVELOPMENT SOCIETY',
#  'SOCIETY FOR NATIONAL INTEGRATION THROUGH RURAL DEVELOPMENT',
#  'Nellore District Weaker Sections Welfare Association',
#  'Gowthami Foundation',
#  'Janakalyan Welfare Society',
#  'Social Welfare Action Development Organisation (SWADO)',
#  'Village Renewal Organisation',
#  'PSS.Educational Development society',
#  'Commissioner of School Education',
#  'GUIDE FOUNDATION FOR DEVELOPMENT (GFFD)',
# ...

# %%
for i in l:
    print(i)
# Out:
# Shama
# dd_natinal
# ISLES Scientific Learning and Educational Society
# Rural Care Ministries
# RRHEDS ( Redemption Research for Health and Educational Development Society)
# Serve Train Educate People's Society-STEPS
# Sanga Mithra Development Association
# Association for Social & Humanize Action
# Technology & Innovation for Social Change
# Welfare Organiosation for Rural League Development (WORLD)
# sunlight educational society
# MAHILA MARGADARSHI
# Rural Development Trust
# SRISAI RURAL DEVELOPMENT SOCIETY
# SOCIETY FOR NATIONAL INTEGRATION THROUGH RURAL DEVELOPMENT
# Nellore District Weaker Sections Welfare Association
# Gowthami Foundation
# Janakalyan Welfare Society
# Social Welfare Action Development Organisation (SWADO)
# Village Renewal Organisation
# PSS.Educational Development society
# Commissioner of School Education
# GUIDE FOUNDATION FOR DEVELOPMENT (GFFD)
# PIOUS SCIENCE SOCIETY
# Creative Action for Necessitous Development From Living Environments(CANDLE)
# ...

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\Rohan Gore\Documents\Selenium\chromedriver.exe")
driver.get("https://guidestarindia.org/Summary.aspx?CCReg=9089")

# %%
notfound=[]
j=0
for i in l:
    try:
        driver.find_element_by_id("SearchBar1_txtSearchQuery").send_keys(i)
        link_path='//*[@id="SearchBar1_btnSearchButton"]'
        driver.find_element_by_xpath(link_path).click()

        link_path='//*[@id="SectionPlaceHolder1"]/table/tbody/tr[4]/td[2]/table/tbody/tr/td/table[1]/tbody/tr[1]/td/table/tbody/tr/td[1]/b/a'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        if i == ele.text:
            link_path='//*[@id="SectionPlaceHolder1"]/table/tbody/tr[4]/td[2]/table/tbody/tr/td/table[1]/tbody/tr[1]/td/table/tbody/tr/td[1]/b/a'
            driver.find_element_by_xpath(link_path).click()

            # Scraping data from guidestar
            link_path='//*[@id="SectionPlaceHolder1_ctl01_DynVariableList4_DynVariableList4ItemContainer0"]/table'
            ele=driver.find_element_by_xpath(link_path)
            print(ele.text)
            Head_Name_Designation_Email.append(ele.text)
            try:
                link_path='//*[@id="SectionPlaceHolder1_ctl01_DynVariableList3_DynVariableList3ItemContainer0"]'
                ele=driver.find_element_by_xpath(link_path)
                print(ele.text)
                Organisation_Name_Designation_Email.append(ele.text)
                print("panda")
            except NoSuchElementException:
                Organisation_Name_Designation_Email.append("NA") 
                print("not found")
                pass

            # Org Profile
            link_path='//*[@id="SectionPlaceHolder1"]/table[1]/tbody/tr[1]/td[2]/table/tbody/tr/td/div/table/tbody/tr[2]/td[5]/a'
            driver.find_element_by_xpath(link_path).click()
            sleep(15)
            print("panda")
            link_path='//*[@id="Anthem_SectionPlaceHolder1_ctl01_ComboControl1_ctl01__"]/fieldset/ul'
            ele=driver.find_element_by_xpath(link_path)
            print(ele.text)
            Beneficiary_Groups.append(ele.text)

            link_path='//*[@id="SectionPlaceHolder1_ctl01_txtPanNum"]/div/span[1]'
            ele=driver.find_element_by_xpath(link_path)
            print(ele.text)
            PAN_NO.append(ele.text)
    except NoSuchElementException:
        notfound.append(i)
        print("not found")
        print(j)
        continue
# Out:
# not found
# 0
# not found
# 0
# not found
# 0
# Rural Care Ministries
# Yonathanu.Karyampudi
# Director/President
# jkaryampudi@yahoo.com
# Show +
# not found
# panda
# Children
# Dalits
# Elderly
# HIV+
# Orphans
# Rural Poor
# AABTR2006A
# Redemption Research for Health and Educational Development Society(RRHEDS)
# Serve, Train, Educate People Society
# Sanga Mithra Development Association
# D.Veerabhadrarao
# Executive Secretary
# samidango@gmail.com
# Show +
# D.Veerabhadrarao
# Secretary
# samidango@gmail.com
# Show +
# panda
# panda
# Adults
# Artisans
# Children
# Commercial Sex Workers
# Dalits
# Disaster Affected
# Domestic Workers
# Elderly
# Farmers / Farm Labourers
# Girl Child
# Healthcare Workers
# HIV+
# Migrants
# Rural Poor
# Street Children
# Students
# Teachers
# Tribals
# Urban poor
# Weavers
# Women
# Youth
# AADTS4810P
# Association for Social and Humanize Action(ASHA)
# Centre for Catalyzing Change
# not found
# 0
# CITIZEN EDUCATIONAL SOCIETY
# ...

# %%
len(PAN_NO)
# Out:
# 398

# %%
len(Beneficiary_Groups)
# Out:
# 398

# %%
len(Organisation_Name_Designation_Email)
# Out:
# 425

# %%
len(Head_Name_Designation_Email)
# Out:
# 425

# %%
df=pd.read_excel("List of NGOs.xlsx")
df.head()
# Out:
#    Sr.No.                        State  \
# 0       1  Andaman and Nicobar Islands
# 1       2  Andaman and Nicobar Islands
# 2       3  Andaman and Nicobar Islands
# 3       4               Andhra Pradesh
# 4       5               Andhra Pradesh
#
#                                                 Name
# 0                                              Shama
# 1                                         dd_natinal
# 2  ISLES Scientific Learning and Educational Society
# 3                              Rural Care Ministries
# 4  RRHEDS ( Redemption Research for Health and Ed...

# %%
lst=[]
lst=df['Name']

# %%
lst
# Out:
# 0                                                   Shama
# 1                                              dd_natinal
# 2       ISLES Scientific Learning and Educational Society
# 3                                   Rural Care Ministries
# 4       RRHEDS ( Redemption Research for Health and Ed...
# 5              Serve Train Educate People's Society-STEPS
# 6                    Sanga Mithra Development Association
# 7                Association for Social & Humanize Action
# 8               Technology & Innovation for Social Change
# 9       Welfare Organiosation for Rural League Develop...
# 10                           sunlight educational society
# 11                                     MAHILA MARGADARSHI
# 12                                Rural Development Trust
# 13                       SRISAI RURAL DEVELOPMENT SOCIETY
# 14      SOCIETY FOR NATIONAL INTEGRATION THROUGH RURAL...
# 15      Nellore District Weaker Sections Welfare Assoc...
# ...

# %%
lst1=list(lst)

# %%
type(lst1)
# Out:
# list

# %%
lst1
# Out:
# ['Shama',
#  'dd_natinal',
#  'ISLES Scientific Learning and Educational Society',
#  'Rural Care Ministries',
#  'RRHEDS ( Redemption Research for Health and Educational Development Society)',
#  "Serve Train Educate People's Society-STEPS",
#  'Sanga Mithra Development Association',
#  'Association for Social & Humanize Action',
#  'Technology & Innovation for Social Change',
#  'Welfare Organiosation for Rural League Development (WORLD)',
#  'sunlight educational society',
#  'MAHILA MARGADARSHI',
#  'Rural Development Trust',
#  'SRISAI RURAL DEVELOPMENT SOCIETY',
#  'SOCIETY FOR NATIONAL INTEGRATION THROUGH RURAL DEVELOPMENT',
#  'Nellore District Weaker Sections Welfare Association',
#  'Gowthami Foundation',
#  'Janakalyan Welfare Society',
#  'Social Welfare Action Development Organisation (SWADO)',
#  'Village Renewal Organisation',
#  'PSS.Educational Development society',
#  'Commissioner of School Education',
#  'GUIDE FOUNDATION FOR DEVELOPMENT (GFFD)',
# ...

# %%
driver.get("https://guidestarindia.org/Organisation.aspx?CCReg=9089")
link_path='//*[@id="Anthem_SectionPlaceHolder1_ctl01_ComboControl1_ctl01__"]/fieldset/ul'
ele=driver.find_element_by_xpath(link_path)
print(ele.text)
# Out:
# Children
# Rural Poor

# %%
Head_Name_Designation_Email
# Out:
# []

# %%
PAN_NO
# Out:
# []

# %%
Beneficiary_Groups
# Out:
# []

# %%
Rural Care Ministries

# %%
driver.find_element_by_id("SearchBar1_txtSearchQuery").send_keys("Rural Care Ministries")
link_path='//*[@id="SearchBar1_btnSearchButton"]'
driver.find_element_by_xpath(link_path).click()

link_path='//*[@id="SectionPlaceHolder1"]/table/tbody/tr[4]/td[2]/table/tbody/tr/td/table[1]/tbody/tr[1]/td/table/tbody/tr/td[1]/b/a'
ele=driver.find_element_by_xpath(link_path)
print(ele.text)
if "Rural Care Ministries" == ele.text:
    link_path='//*[@id="SectionPlaceHolder1"]/table/tbody/tr[4]/td[2]/table/tbody/tr/td/table[1]/tbody/tr[1]/td/table/tbody/tr/td[1]/b/a'
    driver.find_element_by_xpath(link_path).click()
    
    # Scraping data from guidestar
    link_path='//*[@id="SectionPlaceHolder1_ctl01_DynVariableList4_DynVariableList4ItemContainer0"]/table'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Head_Name_Designation_Email.append(ele.text)
    try:
        link_path='//*[@id="SectionPlaceHolder1_ctl01_DynVariableList3_DynVariableList3ItemContainer0"]'
        ele=driver.find_element_by_xpath(link_path)
        print(ele.text)
        Organisation_Name_Designation_Email.append(ele.text)
        print("panda")
    except NoSuchElementException:
        print("not found")
        pass

    # Org Profile
    link_path='//*[@id="SectionPlaceHolder1"]/table[1]/tbody/tr[1]/td[2]/table/tbody/tr/td/div/table/tbody/tr[2]/td[5]/a'
    driver.find_element_by_xpath(link_path).click()
    sleep(15)
    print("panda")
    link_path='//*[@id="Anthem_SectionPlaceHolder1_ctl01_ComboControl1_ctl01__"]/fieldset/ul'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Beneficiary_Groups.append(ele.text)

    link_path='//*[@id="SectionPlaceHolder1_ctl01_txtPanNum"]/div/span[1]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    PAN_NO.append(ele.text)
# Out:
# Rural Care Ministries
# Yonathanu.Karyampudi
# Director/President
# jkaryampudi@yahoo.com
# Show +
# not found
# panda
# Children
# Dalits
# Elderly
# HIV+
# Orphans
# Rural Poor
# AABTR2006A

# %%
for i in l:
    #search box+ search 
    driver.find_element_by_xpath('//*[@id="ngo_name_search"]').send_keys(i)
    link_path='//*[@id="search_form_container"]/div[7]/div[1]/input'
    driver.find_element_by_xpath(link_path).click()
    
    
    
    link_path='//*[@id="example"]/tbody/tr/td[2]/a'
    driver.find_element_by_xpath(link_path).click()
    
    #fetch name and other details
    link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[2]/a'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Name.append(ele.text)


    link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[3]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Registration_No_City_State.append(ele.text)


    link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[5]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Sectors_working.append(ele.text)



    #open
    link_path='/html/body/div[9]/div[1]/div[3]/div/div/div[2]/table/tbody/tr['+str(i)+']/td[2]/a'
    driver.find_element_by_xpath(link_path).click()

    sleep(5)

    link_path1='//*[@id="UniqueID"]' 
    ele=driver.find_element_by_xpath(link_path1)
    print(ele.text)
    unique_id.append(ele.text)


    link_path='//*[@id="reg_with"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Registered_with.append(ele.text)


    link_path='//*[@id="ngo_type"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Types_of_NGO.append(ele.text)


    link_path='//*[@id="ngo_regno"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Registration_No.append(ele.text)


    link_path='//*[@id="rc_upload"]' 
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Copy_of_Registration_Certificate.append(ele.text)

    link_path='//*[@id="pc_upload"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Copy_of_Pan_Card.append(ele.text)

    link_path='//*[@id="ngo_act_name"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Act_name.append(ele.text)

    link_path='//*[@id="ngo_city_p"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    City_of_Registration.append(ele.text)

    link_path='//*[@id="ngo_state_p"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    State_of_Registration.append(ele.text)

    link_path='//*[@id="ngo_reg_date"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Date_of_Registration.append(ele.text)

    link_path='//*[@id="key_issues"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Key_Issues.append(ele.text)

    link_path='//*[@id="operational_states"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Operational_Area_States.append(ele.text)

    link_path='//*[@id="operational_district"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Operational_Area_District.append(ele.text)

    link_path='//*[@id="FCRA_reg_no"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    FCRA_Registration_no.append(ele.text)

    link_path='//*[@id="activities_achieve"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    FCRA_Registration_no.append(ele.text)

    link_path='//*[@id="address"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Address.append(ele.text)

    link_path='//*[@id="city"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    City.append(ele.text)

    link_path='//*[@id="state_p_ngo"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    State.append(ele.text)

    link_path='//*[@id="phone_n"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Telephone.append(ele.text)

    link_path='//*[@id="mobile_n"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Mobile_No.append(ele.text)

    link_path='//*[@id="ngo_web_url"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    Website_Url.append(ele.text)

    link_path='//*[@id="email_n"]'
    ele=driver.find_element_by_xpath(link_path)
    print(ele.text)
    E_mail.append(ele.text)







    #close
    link_path='//*[@id="ngo_info_modal"]/div[2]/div/div[1]/button/span'
    driver.find_element_by_xpath(link_path).click()
    sleep(5)

# %%
ngo_list = pd.DataFrame(Columns=[Name,])
ngo_list.iloc=[]
