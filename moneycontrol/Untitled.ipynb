# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import pickle
import numpy as np
import json

import re
from collections import OrderedDict
from time import strptime

import sys

# %%
df = pd.read_csv('input_dataframe.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#           date  nse_type           name       ltp  change   volume  buy_price  \
# 0  12-Oct-2021  NIFTY 50    Adani Ports    736.90   -0.07  2152513       0.00
# 1  12-Oct-2021  NIFTY 50   Asian Paints  3,323.25    0.52   564524    3323.25
# 2  12-Oct-2021  NIFTY 50      Axis Bank    797.15    1.27  5098502       0.00
# 3  12-Oct-2021  NIFTY 50     Bajaj Auto  3,978.75    3.29  1353877    3978.75
# 4  12-Oct-2021  NIFTY 50  Bajaj Finance  7,855.75    0.49  1099449    7855.75
#
#    sell_price  buy_qty  sell_qty
# 0        0.00      0.0       0.0
# 1        0.00     95.0       0.0
# 2      797.15      0.0    1260.0
# 3        0.00    542.0       0.0
# 4        0.00    290.0       0.0

# %%
driver = webdriver.Chrome(executable_path=r"chromedriver.exe")

# %%
driver.get('https://www.moneycontrol.com/markets/indian-indices/top-nse-50-companies-list/9?classic=true')

# %%
len(driver.find_element_by_class_name("indices").find_element_by_class_name('responsive').find_elements_by_tag_name('tbody')[1].find_elements_by_tag_name('tr'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-13-960506d704be> in <module>
# ----> 1 len(driver.find_element_by_class_name("indices").find_element_by_class_name('responsive').find_elements_by_tag_name('tbody')[1].find_elements_by_tag_name('tr'))
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".indices"}
#   (Session info: chrome=94.0.4606.81)

# %%
datas = driver.find_element_by_class_name("indices").find_element_by_class_name('responsive').find_elements_by_tag_name('tbody')[1].find_elements_by_tag_name('tr')[-1].text
datas
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-14-3ede931fd95e> in <module>
# ----> 1 datas = driver.find_element_by_class_name("indices").find_element_by_class_name('responsive').find_elements_by_tag_name('tbody')[1].find_elements_by_tag_name('tr')[-1].text
#       2 datas
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".indices"}
#   (Session info: chrome=94.0.4606.81)

# %%
datas = len(driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-93-4f5ca9bb688b> in <module>
# ----> 1 datas = len(driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr'))
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=94.0.4606.81)

# %%
datas
# Out:
# 50

# %%
# 0-9 for every col
for d in range(datas):
    name = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[0].text
    ltp = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[1].text
    change = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[2].text
    volume = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[3].text
    buy_price = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[4].text
    sell_price = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[5].text
    buy_qty = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[6].text
    sell_qty = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[7].text
    Open = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[8].text
    prev_close = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[9].text

    #making dictonary
    data ={
        'date': today_date,
        'nse_type': nse_name,
        'name':name,
        'ltp':ltp,
        'change': change,
        'volume':volume,
        'buy_price':buy_price,
        'sell_price':sell_price,
        'buy_qty':buy_qty,
        'sell_qty': sell_qty
     }


    #append it to main data
    main.append(data)
    print("Making JSON")
    #Open and save in json file
    with open("demo.json", 'w', encoding="utf-8") as f:
              json.dump(main, f,indent=4, ensure_ascii=False)

    #creating dataframe
    df = df.append({
        'date': today_date,
        'nse_type': nse_name,
        'name':name,
        'ltp':ltp,
        'change': change,
        'volume':volume,
        'buy_price':buy_price,
        'sell_price':sell_price,
        'buy_qty':buy_qty,
        'sell_qty': sell_qty
     }, ignore_index=True)

    print("Making csv")
    df.to_csv('input_dataframe.csv',columns=["date",'nse_type',"name","ltp","change","volume","buy_price","sell_price","buy_qty","sell_qty"])

# %%
name
# Out:
# 'Wipro'

# %%
name = datas.split(' ')[0]
name
# Out:
# 'Adani'

# %%
ltp = datas.split(' ')[1].split(" ")[0]
ltp
# Out:
# 'Ports'

# %%
change = datas.split('\n')[1].split(" ")[1]
change
# Out:
# '-0.07'

# %%
volume = datas.split('\n')[1].split(" ")[2]
volume
# Out:
# '2152513'

# %%
buy_price = datas.split('\n')[1].split(" ")[3]
buy_price
# Out:
# '0.00'

# %%
sell_price = datas.split('\n')[1].split(" ")[4]
sell_price
# Out:
# '0.00'

# %%
buy_qty = datas.split('\n')[1].split(" ")[5]
buy_qty
# Out:
# '0.00'

# %%
sell_qty = datas.split('\n')[1].split(" ")[6]
sell_qty
# Out:
# '0.00'

# %%
#to get length of the links
len(driver.find_elements_by_class_name('cnbc_tabs')[1].find_element_by_class_name('accordion_list').find_elements_by_tag_name('li'))
# Out:
# 36

# %%
#to get links
driver.find_elements_by_class_name('cnbc_tabs')[1].find_element_by_class_name('accordion_list').find_elements_by_tag_name('li')[-1].find_element_by_tag_name('a').text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-1a5abed0b70b> in <module>
#       1 #to get links
# ----> 2 driver.find_elements_by_class_name('cnbc_tabs')[1].find_element_by_class_name('accordion_list').find_elements_by_tag_name('li')[-1].find_element_by_tag_name('a').text
#
# IndexError: list index out of range

# %%
# click on types => all indices
driver.find_element_by_id('indicesDropdown').find_elements_by_tag_name('option')[-1].click()

# %%
# to get length of nse list  
len(driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList'))
# Out:
# 11

# %%
# name
driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList')[0].text

# %%
# links
driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList')[1].find_element_by_tag_name('a').get_attribute('href')

# %%
s = 'https://www.moneycontrol.com/markets/indian-indices/top-nsesmallcap-50-companies-list/113?classic=true'
s
# Out:
# 'https://www.moneycontrol.com/markets/indian-indices/top-nsesmallcap-50-companies-list/113?classic=true'

# %%
s.split("/")[-2]
# Out:
# 'top-nsesmallcap-50-companies-list'

# %%
import time
from datetime import datetime
from datetime import date

# to get today's date
today = date.today()

# %%
today
# Out:
# datetime.date(2021, 10, 12)

# %%
today.strftime("%d-%b-%Y")
# Out:
# '12-Oct-2021'

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import pickle
import numpy as np
import json


import re
from collections import OrderedDict
from time import strptime

import sys

import time
from datetime import datetime
from datetime import date

today = date.today()
today_date = today.strftime("%d-%b-%Y")

# list of dictionary
main = []

try:
    df = pd.read_csv('input_dataframe.csv')
    df.drop('Unnamed: 0', axis=1, inplace=True)
except:
    # Initializing data Frame
    df = pd.DataFrame()

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(chrome_options=options,executable_path=r"chromedriver.exe")


input_link = str(input("Please paste link here... "))
driver.get(input_link)

driver.execute_script("window.scrollBy(0,925)", "")

sleep(20)
# click on types => all indices
driver.find_element_by_id('indicesDropdown').find_elements_by_tag_name('option')[-1].click()

sleep(5)
#to get length of the nse links
nse_links_len = len(driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList'))

nse_links = []
nse_names = []

sleep(5)
for nl in range(nse_links_len):
    #to get links
    nl_link = driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList')[nl].find_element_by_tag_name('a').get_attribute('href')
    nse_links.append(nl_link)
    
    # name
    nse_name = driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList')[nl].text
    nse_names.append(nse_name)

#getting data
for nse_link,nse_name in zip(nse_links,nse_names):
    try:
        print("NSE TYPE => ", nse_name)
        driver.get(nse_link)
        sleep(5)
        
        #length of stocks list
        stocklist_len = len(driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr'))    
        
        # 0-9 for every col
        for d in range(stocklist_len):
            try:
                name = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[0].text
                ltp = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[1].text
                change = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[2].text
                volume = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[3].text
                buy_price = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[4].text
                sell_price = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[5].text
                buy_qty = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[6].text
                sell_qty = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[7].text
                Open = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[8].text
                prev_close = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[9].text


                #making dictonary
                data ={
                    'date': today_date,
                    'nse_type': nse_name,
                    'name':name,
                    'ltp':ltp,
                    'change': change,
                    'volume':volume,
                    'buy_price':buy_price,
                    'sell_price':sell_price,
                    'buy_qty':buy_qty,
                    'sell_qty': sell_qty,
                    'Open': Open,
                    'Prev Close':prev_close
                 }


                #append it to main data
                main.append(data)
                print("Making JSON")
                #Open and save in json file
                with open("demo.json", 'w', encoding="utf-8") as f:
                          json.dump(main, f,indent=4, ensure_ascii=False)

                #creating dataframe
                df = df.append({
                    'date': today_date,
                    'nse_type': nse_name,
                    'name':name,
                    'ltp':ltp,
                    'change': change,
                    'volume':volume,
                    'buy_price':buy_price,
                    'sell_price':sell_price,
                    'buy_qty':buy_qty,
                    'sell_qty': sell_qty,
                    'Open': Open,
                    'Prev Close':prev_close
                 }, ignore_index=True)

                print("Making csv")
                df.to_csv('input_dataframe.csv',columns=["date",'nse_type',"name","ltp","change","volume","buy_price","sell_price","buy_qty","sell_qty", "Open", "Prev Close"])
            except Exception as e:
                print(e)
    except Exception as e:
                print(e)
# Out:
# Please paste link here... https://www.moneycontrol.com/markets/indian-indices/top-nse-50-companies-list/9?classic=true
# NSE TYPE =>  NIFTY 50
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# NSE TYPE =>  NIFTY BANK
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# NSE TYPE =>  NIFTY Midcap 100
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# NSE TYPE =>  NIFTY NEXT 50
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# NSE TYPE =>  NIFTY 100
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# NSE TYPE =>  Nifty 200
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# Making JSON
# Making csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-ffe5f12c8193> in <module>
#      81                 buy_price = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[4].text
#      82                 sell_price = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[5].text
# ---> 83                 buy_qty = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[6].text
#      84                 sell_qty = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[7].text
#      85                 Open = driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')[d].find_elements_by_tag_name('td')[8].text
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webelement.py in find_elements_by_tag_name(self, name)
#     318             elements = element.find_elements_by_tag_name('h1')
#     319         """
# --> 320         return self.find_elements(by=By.TAG_NAME, value=name)
#     321
#     322     def find_element_by_xpath(self, xpath):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webelement.py in find_elements(self, by, value)
#     683
#     684         return self._execute(Command.FIND_CHILD_ELEMENTS,
# --> 685                              {"using": by, "value": value})['value']
#     686
#     687     def __hash__(self):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
#      78             return self.request_encode_body(
# ---> 79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#      81
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\users\gorer\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
len(driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList'))
# Out:
# 39

# %%
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(chrome_options=options,executable_path=r"chromedriver.exe")
driver.get("https://www.moneycontrol.com/markets/indian-indices/top-nse-50-companies-list/9?classic=true")
# Out:
# c:\users\gorer\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: use options instead of chrome_options
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
nse_links_len = len(driver.find_element_by_class_name('ntlist').find_elements_by_class_name('indicesList'))

# %%
nse_links_len
# Out:
# 39

# %%
stocklist_len = len(driver.find_element_by_id('tableslider').find_element_by_tag_name('tbody').find_elements_by_tag_name('tr'))

# %%
df.head()
# Out:
#           date  nse_type           name       ltp change   volume buy_price  \
# 0  12-Oct-2021  NIFTY 50    Adani Ports    736.90  -0.07  2152513         0
# 1  12-Oct-2021  NIFTY 50   Asian Paints  3,323.25   0.52   564524   3323.25
# 2  12-Oct-2021  NIFTY 50      Axis Bank    797.15   1.27  5098502         0
# 3  12-Oct-2021  NIFTY 50     Bajaj Auto  3,978.75   3.29  1353877   3978.75
# 4  12-Oct-2021  NIFTY 50  Bajaj Finance  7,855.75   0.49  1099449   7855.75
#
#   sell_price buy_qty sell_qty
# 0          0       0        0
# 1          0      95        0
# 2     797.15       0     1260
# 3          0     542        0
# 4          0     290        0
